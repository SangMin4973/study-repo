# %% [markdown]
# #### 서브워드 분리(Subword segmentation)
# - 하나의 단어를 더 작은 단위의 의미있는 서브워드들로 분리하는 전처리 작업
#
# #### BPE(Byte Pair Encoding)
# - 연속적으로 가장 많이 등장한 글자의 쌍을 찾아서 하나의 글자로 병합하는 방식
# ```
# 1)
# aaabdaaabac
# 2) Z = aa
# ZabdZabac
# 3) Y = ab
# ZYbdZYac
# 4) X = ZY
# XbdXac
# ```
#
# #### 자연어 처리에서의 BPE
# - 자연어 처리에서의 BPE는 서브워드 분리 알고리즘

# %%
import re, collections
from IPython.display import display, Markdown, Latex

# %%
num_merges = 10

# %%
dictionary = {'l o w </w>' : 5,
         'l o w e r </w>' : 2,
         'n e w e s t </w>':6,
         'w i d e s t </w>':3
         }

# %%
def get_stats(dictionary):
    # 유니그램의 pair들의 빈도수 카운트
    # defaultdict(int): 딕셔너리에 없는 키가 입력될 시 0을 자동 생성
    pairs = collections.defaultdict(int)
    for word, freq in dictionary.items():
        # ' '로 구분하여 리스트 생성
        symbols = word.split()
        for i in range(len(symbols)-1):
            pairs[symbols[i], symbols[i+1]] += freq
        print('현재 pair들의 빈도수: ', dict(pairs))
    return pairs

def merge_dictionary(pair, v_in):
    v_out = {}
    # re.escape(' '.join(text)):
    # 1. text = ["hello", "world"]
    # 2. re.escape(' '.join(text))
    #    -> hello\ world
    bigram = re.escape(' '.join(pair))
    # 앞뒤가 공백이거나 시작인 패턴을 찾음
    p = re.compile(r'(?<!\S)' + bigram + r'(?!\S)')
    for word in v_in:
        w_out = p.sub(''.join(pair), word)
        v_out[w_out] = v_in[word]
    return v_out

# %%
bpe_codes = {}
bpe_codes_reverse = {}

for i in range(num_merges):
    display(Markdown('### Iteration {}'.format(i+1)))
    pairs = get_stats(dictionary)
    best = max(pairs, key=pairs.get)
    dictionary = merge_dictionary(best, dictionary)

    bpe_codes[best] = i
    bpe_codes_reverse[best[0] + best[1]] = best

    print("new merge: {}".format(best))
    print("dictionary: {}".format(dictionary))
# Out:
# ### Iteration 1
# 현재 pair들의 빈도수:  {('l', 'o'): 5, ('o', 'w'): 5, ('w', '</w>'): 5}
# 현재 pair들의 빈도수:  {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2}
# 현재 pair들의 빈도수:  {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 8, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('e', 's'): 6, ('s', 't'): 6, ('t', '</w>'): 6}
# 현재 pair들의 빈도수:  {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 8, ('e', 'r'): 2, ('r', '</w>'): 2, ('n', 'e'): 6, ('e', 'w'): 6, ('e', 's'): 9, ('s', 't'): 9, ('t', '</w>'): 9, ('w', 'i'): 3, ('i', 'd'): 3, ('d', 'e'): 3}
# new merge: ('e', 's')
# dictionary: {'l o w </w>': 5, 'l o w e r </w>': 2, 'n e w es t </w>': 6, 'w i d es t </w>': 3}
# ### Iteration 2
# 현재 pair들의 빈도수:  {('l', 'o'): 5, ('o', 'w'): 5, ('w', '</w>'): 5}
# 현재 pair들의 빈도수:  {('l', 'o'): 7, ('o', 'w'): 7, ('w', '</w>'): 5, ('w', 'e'): 2, ('e', 'r'): 2, ('r', '</w>'): 2}
# ...

# %%
print(bpe_codes)
# Out:
# {('e', 's'): 0, ('es', 't'): 1, ('est', '</w>'): 2, ('l', 'o'): 3, ('lo', 'w'): 4, ('n', 'e'): 5, ('ne', 'w'): 6, ('new', 'est</w>'): 7, ('low', '</w>'): 8, ('w', 'i'): 9}

# %%
# OOV(OutOfVocabulary) 대처하기

def get_pairs(word):
    """단어 안의 모든 심볼쌍(symbol pair)의 집합을 반환한다.
    예시) word = ('l', 'o', 'w', 'e', 'r')
        symbol pair = (l,o),(o,w),(w,e),(e,r)
        반환값: {('l','o'), ('o','w'), ('w','e'), ('e','r')}
    단어는 symbol들의 튜플로 표현됨"""

    pairs = set()
    prev_char = word[0]
    for char in word[1:]:
        pairs.add((prev_char, char))
        prev_char = char
    return pairs

def encode(orig):
    """BPE merge 연산들의 리스트를 기반으로 단어를 인코딩한다.
    이 merge 연산들은 순차적으로 적용된다."""

    word = tuple(orig) + ('</w>',)
    display(Markdown("__word split into characters:__ <tt>{}</tt>".format(word)))

    pairs = get_pairs(word)

    if not pairs:
        return orig
    
    iteration = 0
    while True:
        iteration += 1
        display(Markdown("__Iteration {}__".format(iteration)))

        print("bigrams in the word: {}".format(pairs))
        bigram = min(pairs, key=lambda pair:bpe_codes.get(pair, float('inf')))
        print("candidate for merging: {}".format(bigram))
        if bigram not in bpe_codes:
            display(Markdown("__Candidate not in BPE merges, algorithm stops.__"))
            break
        first, second = bigram
        new_word = []
        i = 0
        while i<len(word):
            try:
                j = word.index(first, i)
                new_word.extend(word[i:j])
                i = j
            except:
                new_word.extend(word[i:])
                break

            if word[i]==first and i<len(word)-1 and word[i+1]==second:
                new_word.append(first+second)
                i += 2
            else:
                new_word.append(word[i])
                i += 1

        new_word = tuple(new_word)
        word = new_word
        print("word after merging: {}".format(word))
        if len(word)==1:
            break
        else:
            pairs = get_pairs(word)
        
    if word[-1]=='</w>':
        word = word[:-1]
    elif word[-1].endswith('</w>'):
        word = word[:-1] + (word[-1].replace('</w>', ''),)
    
    return word

# %%
encode("loki")
# Out:
# __word split into characters:__ <tt>('l', 'o', 'k', 'i', '</w>')</tt>
# __Iteration 1__
# bigrams in the word: {('i', '</w>'), ('o', 'k'), ('k', 'i'), ('l', 'o')}
# candidate for merging: ('l', 'o')
# word after merging: ('lo', 'k', 'i', '</w>')
# __Iteration 2__
# bigrams in the word: {('lo', 'k'), ('k', 'i'), ('i', '</w>')}
# candidate for merging: ('lo', 'k')
# __Candidate not in BPE merges, algorithm stops.__
# ('lo', 'k', 'i')

# %%
encode("lowest")
# Out:
# __word split into characters:__ <tt>('l', 'o', 'w', 'e', 's', 't', '</w>')</tt>
# __Iteration 1__
# bigrams in the word: {('l', 'o'), ('w', 'e'), ('s', 't'), ('o', 'w'), ('t', '</w>'), ('e', 's')}
# candidate for merging: ('e', 's')
# word after merging: ('l', 'o', 'w', 'es', 't', '</w>')
# __Iteration 2__
# bigrams in the word: {('w', 'es'), ('es', 't'), ('l', 'o'), ('o', 'w'), ('t', '</w>')}
# candidate for merging: ('es', 't')
# word after merging: ('l', 'o', 'w', 'est', '</w>')
# __Iteration 3__
# bigrams in the word: {('o', 'w'), ('est', '</w>'), ('w', 'est'), ('l', 'o')}
# candidate for merging: ('est', '</w>')
# word after merging: ('l', 'o', 'w', 'est</w>')
# __Iteration 4__
# bigrams in the word: {('o', 'w'), ('w', 'est</w>'), ('l', 'o')}
# candidate for merging: ('l', 'o')
# word after merging: ('lo', 'w', 'est</w>')
# __Iteration 5__
# bigrams in the word: {('w', 'est</w>'), ('lo', 'w')}
# candidate for merging: ('lo', 'w')
# word after merging: ('low', 'est</w>')
# ...

# %%
encode("lowing")
# Out:
# __word split into characters:__ <tt>('l', 'o', 'w', 'i', 'n', 'g', '</w>')</tt>
# __Iteration 1__
# bigrams in the word: {('n', 'g'), ('g', '</w>'), ('l', 'o'), ('w', 'i'), ('i', 'n'), ('o', 'w')}
# candidate for merging: ('l', 'o')
# word after merging: ('lo', 'w', 'i', 'n', 'g', '</w>')
# __Iteration 2__
# bigrams in the word: {('n', 'g'), ('g', '</w>'), ('lo', 'w'), ('w', 'i'), ('i', 'n')}
# candidate for merging: ('lo', 'w')
# word after merging: ('low', 'i', 'n', 'g', '</w>')
# __Iteration 3__
# bigrams in the word: {('n', 'g'), ('low', 'i'), ('i', 'n'), ('g', '</w>')}
# candidate for merging: ('n', 'g')
# __Candidate not in BPE merges, algorithm stops.__
# ('low', 'i', 'n', 'g')
