# %% [markdown]
# ## 역전파
# #### 순전파
# $z_1 = W_1x_1 + W_2x_2$
#
# $z_2 = W_3x_1 + W_4x_2$
#
# $h_1 = sigmoid(z_1)$
#
# $h_2 = sigmoid(z_2)$
#
# $z_3 = W_5h_1 + W_6h_2$
#
# $z_4 = W_7h_1 + W_8h_2$
#
# $o_1 = sigmoid(z3)$
#
# $o_2 = sigmoid(z4)$
#
# $E_{o1} = \displaystyle\frac{1}{2}(target_{o1} - output_{o1})^2$
#
# $E_{o2} = \displaystyle\frac{1}{2}(target_{o2} - output_{o2})^2$
#
# $E_{total} = E_{o1} + E_{o2}$
#
# #### 가중치 업데이트 과정
# $\displaystyle\frac{\partial E_{total}}{\partial W_5} = \displaystyle\frac{\partial E_{total}}{\partial o_1} \times \displaystyle\frac{\partial o_1}{\partial z_3} \times \displaystyle\frac{\partial z_3}{\partial W_6} \rightarrow {W_6}^+$
