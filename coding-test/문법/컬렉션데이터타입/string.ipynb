# %% [markdown]
# #### 문자열(String)
# - 이뮤터블 객체

# %%
# 문자열을 리스트에 담아두고 한 번에 결합
string_list = ['He', "llo"]
result = "".join(string_list)
result
# Out:
# 'Hello'

# %%
# 문자열 수정
string = "Hello"
string = string.replace("l", "")
print(string)
# Out:
# Heo
